# %%
import pandas as pd

df_attack = pd.read_csv('terrorist_attacks_new.csv',usecols=['Entity','Code','Year','Terrorist attacks'])

# %%
df_attack.head()
# Out:
#         Entity Code  Year  Terrorist attacks
# 0  Afghanistan  AFG  1970                  0
# 1  Afghanistan  AFG  1971                  0
# 2  Afghanistan  AFG  1972                  0
# 3  Afghanistan  AFG  1973                  1
# 4  Afghanistan  AFG  1974                  0

# %%
import seaborn as sns

sns.scatterplot(data = df_attack, x = 'Entity', y = 'Code', hue = 'Year')
# Out:
# <Axes: xlabel='Entity', ylabel='Code'>

# %%
sns.scatterplot(data = df_attack, x = 'Year', y = 'Code', hue = 'Terrorist attacks')
# Out:
# <Axes: xlabel='Year', ylabel='Code'>

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_attack[['Year', 'Code']], df_attack[['Terrorist attacks']], test_size=0.33, random_state=0)

# %%
from sklearn import preprocessing

X_train_norm = preprocessing.normalize(X_train)
X_test_norm = preprocessing.normalize(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11856\677972675.py in ?()
#       1 from sklearn import preprocessing
#       2
# ----> 3 X_train_norm = preprocessing.normalize(X_train)
#       4 X_test_norm = preprocessing.normalize(X_test)
#
# c:\Users\taksh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py in ?(*args, **kwargs)
#     210                         prefer_skip_nested_validation or global_skip_validation
#     211                     )
#     212                 ):
#     213                     return func(*args, **kwargs)
# --> 214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#     216                 # the function to delegate validation to the estimator, but we replace
# ...

# %%
from sklearn import KMeans

kmeans = KMeans(n_clusters = 3, random_state = 0, n_init='auto')
kmeans.fit(X_train_norm)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from sklearn import KMeans
#       3 kmeans = KMeans(n_clusters = 3, random_state = 0, n_init='auto')
#       4 kmeans.fit(X_train_norm)
#
# ImportError: cannot import name 'KMeans' from 'sklearn' (c:\Users\taksh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\__init__.py)
